# %% [markdown]
# <a href="https://colab.research.google.com/github/HanifFaishalH/PCVK25_3F_15/blob/master/Week1_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRAKTIKUM D2

# %% [markdown]
# **Langkah 1**
#
# Menggunakan beberapa library yang akan digunakan

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# **Langkah 2**
#
# Membaca dan menampilkan image

# %%
urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://avatars.githubusercontent.com/u/143581681?s=400&u=23a043bb2cea51cc220b46c1225afd4e6104b1a8&v=4"
]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  finale_frame = cv.hconcat((image, image_2))
  cv2_imshow(finale_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=348x174>

# %% [markdown]
# **Langkah 3**
#
# Melihat ukuran file

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  174  x  174
# <PIL.Image.Image image mode=RGB size=174x174>

# %% [markdown]
# **Langkah 4**
#
# Mengakses pixel dengan memberikan garis horizontal berwarna putih di tengah image

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=348x174>

# %% [markdown]
# **Pertanyaan praktikum D2**
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua library tersebut harus digunakan dalam praktikum
# sesi ini?
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# ![Screenshot 2025-08-26 113557.png](data:image/png;base64,...)
#
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak
# dilakukan?
#
# 4. Perhatikan potongan kode progam berikut :
#
# ![image.png](data:image/png;base64,...)
#
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!

# %% [markdown]
# **Jawaban**
#
# 1. Karena, Google Colab memiliki kelebihan seperti berikut :
# * Gratis dan berbasis cloud sehingga bisa mengakses semua library tanpa melakukan instalasi.
# * Bisa dipakai tanpa harus memiliki hardware yang kuat
# * Dapat terintegrasi dengan Google Drive
# * Mudah melakukan kolaborasi
#
#
#
# ---
#
#
# 2. Fungsi masing-masing library
#
# * numpy : komputasi numerik dan digunakan untuk array multidimensi
# * pandas : analisis data berbasis tabel. Digunakan untuk mengelola dataset, statistik, dan integrasi dengan CSV, Excel, SQL
# * cv2 : Library Computer Vision untuk membaca atau menulis gambar dan video, mentransformasi warna, mendeteksi objek, dll.
# * cv2_imshow : fungsi khusus di Google Colab untuk menampilkan gambar dengan cv.imshow().
# * skimage : library khusus untuk image processing. Fokus di ilmu citra digital.
# * PIL : digunakan untuk cropping, resize, convert, dll. Dapat digunakan untuk berbagai format gambar seperti JPG, PNG, GIF, dll.
# * matplotlib : digunakan untuk visualisasi data.
#
# Apakah semuanya dipakai? Tidak. Di praktikum ini, hanya menggunakan cv2, skimage, cv2_imshow, dan numpy
#
# ---
# 3. Kode tersbut digunakan untuk mengubah ukuran citra(gambar). "(0,0)" digunakan untuk mengubah ukuran gambar menggunakan skala. Dengan "fx=0.5" dan "fy=0.5", skala lebar x dan y berubah menjadi 50% sehingga gambarnya memiliki ukuran setengah dari ukuran asli.
#
# Apabila kode ini dihapus, gambar akan tetap muncul dengan ukuran asli.
#
# ---
# 4. kode [255,255,255] adalah kode warna untuk RGB. dengan nilai tersebut,garis yang memotong gambar secara horizotal berwarna putih
#
# ---
# 5. Keterkaitan antara piksel dan resolusi gambar adalah ketika resolusi gambar semakin tinggi, jumlah pixelnya semakin banyak sehingga detail gambar menjadi lebih jelas, tajam, dan bisa diperbesar tanpa pecah. Akan tetapi, jika resolusi gambar makin rendah, jumlah pixelnya semakin sedikit sehingga detail gambar lebih kabur dan jika diperbesar muncul pecahan kotak-kotak.

# %% [markdown]
# # Tugas Praktikum D2

# %% [markdown]
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran **bold text**

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=348x174>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(min(tinggi, lebar)):
    image_3[y, y] = [255,255,255]

    image_3[y, lebar - y - 1] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=348x174>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan
# panjang tertentu

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

y_tengah = tinggi // 2

panjang = 50
x_awal = (lebar // 2) - (panjang // 2)
x_akhir = (lebar // 2) + (panjang // 2)

cv.line(image_3, (x_awal, y_tengah), (x_akhir, y_tengah), (255, 255, 255), 2)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=348x174>

# %% [markdown]
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

x1, y1 = 25, 75
x2, y2 = 75, 25

cv.rectangle(image_3, (x1, y1), (x2, y2), (255, 255, 255), -1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=348x174>
